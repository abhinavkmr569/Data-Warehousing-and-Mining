# %% [markdown]
# Name: [Abhinav Kumar](https://github.com/abhinavkmr569)
#
# Roll No.: I026
#
# DWM LAB 7 - To Implement K nearest neighbor algorithm.
#
# [Open In Colab](https://colab.research.google.com/drive/1EWioV_xcvIPZdzDLuHGUWLmH_W2_uV7I?usp=sharing)

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Importing Dataset

# %%
df = pd.read_csv("iris.data", header = None)
df.columns = ['Sepal Length', 'Sepal Width', 'Petal Length', 'Petal Width', 'Class']
df
# Out:
#      Sepal Length  Sepal Width  Petal Length  Petal Width           Class
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 145           6.7          3.0           5.2          2.3  Iris-virginica
# 146           6.3          2.5           5.0          1.9  Iris-virginica
# 147           6.5          3.0           5.2          2.0  Iris-virginica
# 148           6.2          3.4           5.4          2.3  Iris-virginica
# 149           5.9          3.0           5.1          1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
convert_dict = {'Sepal Length': float, 'Sepal Width': float, 'Petal Length': float, 'Petal Width': float, 'Class': str}

df = df.astype(convert_dict) 
print(df.dtypes)
# Out:
# Sepal Length    float64
# Sepal Width     float64
# Petal Length    float64
# Petal Width     float64
# Class            object
# dtype: object

# %%
train=df.sample(frac=0.67,random_state=32) 
test=df.drop(train.index)

# %%
train
# Out:
#      Sepal Length  Sepal Width  Petal Length  Petal Width            Class
# 55            5.7          2.8           4.5          1.3  Iris-versicolor
# 22            4.6          3.6           1.0          0.2      Iris-setosa
# 26            5.0          3.4           1.6          0.4      Iris-setosa
# 56            6.3          3.3           4.7          1.6  Iris-versicolor
# 134           6.1          2.6           5.6          1.4   Iris-virginica
# ..            ...          ...           ...          ...              ...
# 103           6.3          2.9           5.6          1.8   Iris-virginica
# 75            6.6          3.0           4.4          1.4  Iris-versicolor
# 149           5.9          3.0           5.1          1.8   Iris-virginica
# 47            4.6          3.2           1.4          0.2      Iris-setosa
# 122           7.7          2.8           6.7          2.0   Iris-virginica
#
# [100 rows x 5 columns]

# %%
test
# Out:
#      Sepal Length  Sepal Width  Petal Length  Petal Width            Class
# 3             4.6          3.1           1.5          0.2      Iris-setosa
# 4             5.0          3.6           1.4          0.2      Iris-setosa
# 6             4.6          3.4           1.4          0.3      Iris-setosa
# 9             4.9          3.1           1.5          0.1      Iris-setosa
# 11            4.8          3.4           1.6          0.2      Iris-setosa
# 24            4.8          3.4           1.9          0.2      Iris-setosa
# 29            4.7          3.2           1.6          0.2      Iris-setosa
# 30            4.8          3.1           1.6          0.2      Iris-setosa
# 35            5.0          3.2           1.2          0.2      Iris-setosa
# 42            4.4          3.2           1.3          0.2      Iris-setosa
# 43            5.0          3.5           1.6          0.6      Iris-setosa
# ...

# %%
df_numpy = train.to_numpy()

# %% [markdown]
# ---
# ### Using Test DataFrame

# %%
test_l = []
fin = []
test1 = test.to_numpy()

def test_list(c,k):
  for i in range(test1.shape[0]):
    for j in range(4):
      test_l.append(test1[i][j])
    #print(test_l)
    eucli_dist(test_l,c,k,fin)
    test_l.clear()

# %%
def eucli_dist(new_data_point,c,k,fin):
    eu_di = []

    for i in range(df_numpy.shape[0]):
      dist = 0.0
      for j in range(4):
        dist = dist + pow(float(df_numpy[i][j])-new_data_point[j],2)
      eu_di.append(pow(dist,0.5))

    eu_di

    train["Euclidean Distance"] = eu_di

    prediction(new_data_point,c,k,fin)

# %%
def prediction(new_data_point,c,k,fin):

  if (c!=1):
    
    train.drop(columns = ["Euclidean Distance"])

    df1 = train.sort_values(by=['Euclidean Distance']) 

    df1 = df1.iloc[:k,:]
    
    counts = dict(df1["Class"].value_counts())

    final_class = max(counts, key=counts.get) 
    print("\n\033[34m Prediction of class for data point {}: \033[1m{} \033[0m".format(new_data_point,final_class)) 

    fin.append(final_class)
    
  else:

    df1 = train.sort_values(by=['Euclidean Distance']) 

    df1 = df1.iloc[:k,:]

    counts = dict(df1["Class"].value_counts())

    final_class = max(counts, key=counts.get) 
    print("\n\033[34m Prediction of class for data point {}: \033[1m{} \033[0m".format(new_data_point,final_class)) 

    fin.append(final_class)

    train.drop(columns = ["Euclidean Distance"])

# %% [markdown]
# ### Accuracy

# %%
def acc():
  e = list(zip(list(test["Class"]),fin))
  e1 = np.array(e)
  u = int(0)
  for i in range(e1.shape[0]):
    for j in range(e1.shape[1]):
      if (e1[i][0]!=e1[i][1]):
        u+=1
      else:
        pass

  print("\n \033[32mAccuracy: \033[1m{} % \033[0m".format(((e1.shape[0]-u)/(e1.shape[0]))*100))

# %% [markdown]
# ---
# ### Using User Provided Dataset

# %%
def prediction1(c,k):
  new_data_point = []
  column_features = ['Sepal Length', 'Sepal Width', 'Petal Length', 'Petal Width']
  # Sepal Length, Sepal Width, Petal Length and Petal Width.

  
  for i in range(4):
    new_data_point.append(float(input("Enter the {}: ".format(column_features[i]))))
  

  if (c!=1):
    
    df_numpy = train.to_numpy()    
    train.drop(columns = ["Euclidean Distance"])
    

    # Calculating Euclidean Distance 

    eu_di = []

    for i in range(df_numpy.shape[0]):
      dist = 0.0
      for j in range(4):
        dist = dist + pow(float(df_numpy[i][j])-new_data_point[j],2)
      eu_di.append(pow(dist,0.5))

    eu_di

    train["Euclidean Distance"] = eu_di

    df1 = train.sort_values(by=['Euclidean Distance']) 
    df1 = df1.iloc[:k,:]
      
    counts = dict(df1["Class"].value_counts())

    final_class = max(counts, key=counts.get) 

    print("\n\033[32mProbability of the class being {} is {} \033[0m".format(final_class,(counts[final_class]/k)))

    print("\n\033[34m Prediction of class for data point {}: \033[1m{} \033[0m".format(new_data_point,final_class)) 
    
  else:

    df_numpy = train.to_numpy()

    # Calculating Euclidean Distance 
    
    eu_di = []

    for i in range(df_numpy.shape[0]):
      dist = 0.0
      for j in range(4):
        dist = dist + pow(float(df_numpy[i][j])-new_data_point[j],2)
      eu_di.append(pow(dist,0.5))

    eu_di

    train["Euclidean Distance"] = eu_di
    
      
    # k = int(input("\nEnter value of k: "))

    df1 = train.sort_values(by=['Euclidean Distance']) 

    df1 = df1.iloc[:k,:]

      #print(df1)

    counts = dict(df1["Class"].value_counts())

      #print(counts)

    final_class = max(counts, key=counts.get) 

    print("\n\033[32mProbability of the class being {} is {} \033[0m".format(final_class,(counts[final_class]/k)))

    print("\n\033[34m Prediction of class for data point {}: \033[1m{} \033[0m".format(new_data_point,final_class)) 

    train.drop(columns = ["Euclidean Distance"])

# %% [markdown]
# ---
# ### Run

# %%
print("Welcome: ")
c = int(0)
d = int(0)

k = int(input("\n\033[32mEnter value of k: \033[0m"))

while(True):
  print("\nPress 1 to predict class: ")
  print("Press 2 to exit: ")

  try:
    a = int(input("\nEnter your choice: "))
  except ValueError:
    print("Please enter a number (1-2).")

  if (a==1):
    print("\nPress 1 to provide your own datapoint (Sepal Length, Sepal Width, Petal Length and Petal Width): ")
    print("Press 2 to use the test dataframe: ")

    try:
      b = int(input("\nEnter your choice: "))
    except ValueError:
      print("Please enter a number (1-2).")

    if (b==1):
      d+=1
      prediction1(d,k)

    elif (b==2):
      print("\n\033[32mUsing Test Dataframe: \033[0m")
      c+=1
      test_list(c,k)
      acc()

  elif (a==2):
    print("Thankyou!")
    break
  else:
    print("Please enter a valid option.")
# Out:
# Welcome:
#
# Enter value of k: 3
#
# Press 1 to predict class:
# Press 2 to exit:
#
# Enter your choice: 1
#
# Press 1 to provide your own datapoint (Sepal Length, Sepal Width, Petal Length and Petal Width):
# Press 2 to use the test dataframe:
#
# Enter your choice: 1
# Enter the Sepal Length: 6.2
# Enter the Sepal Width: 3.2
# Enter the Petal Length: 5.4
# Enter the Petal Width: 1.1
#
# Probability of the class being Iris-virginica is 1.0
#
#  Prediction of class for data point [6.2, 3.2, 5.4, 1.1]: Iris-virginica
#
# Press 1 to predict class:
# Press 2 to exit:
#
# Enter your choice: 1
#
# Press 1 to provide your own datapoint (Sepal Length, Sepal Width, Petal Length and Petal Width):
# Press 2 to use the test dataframe:
#
# Enter your choice: 2
#
# Using Test Dataframe:
#
#  Prediction of class for data point [4.6, 3.1, 1.5, 0.2]: Iris-setosa
#
#  Prediction of class for data point [5.0, 3.6, 1.4, 0.2]: Iris-setosa
#
# ...
